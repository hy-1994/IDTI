# %%
# %run simulated_data.py
# Out:
# The result folder ./IDTI exists! IDTI overwrite it. To avoid the overwriting, try the -o parameter.
# filtered out 0 cells that are detected in less than 200 genes
#
# filtered out 224 genes that are detected in less than 3 cells
#
# Normalize data to 10000.0 count ...
#
# transfor data...
#
# scale data with the method of MinMaxScaler...
#
# basic partitions with timepoints...
#
# calculate ID and output results...
